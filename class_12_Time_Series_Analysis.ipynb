# %% [markdown]
# <a href="https://colab.research.google.com/github/tbmih/bankingproject/blob/main/class_12_Time_Series_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/phamdinhkhanh/vnquant
# %cd vnquant
# !python setup.py install
# Out:
# Cloning into 'vnquant'...
# remote: Enumerating objects: 263, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 263 (delta 23), reused 22 (delta 22), pack-reused 237
# Receiving objects: 100% (263/263), 1.02 MiB | 6.47 MiB/s, done.
# Resolving deltas: 100% (122/122), done.
# /content/vnquant
# warning: pypandoc module not found, could not convert Markdown to RST
# running install
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating vnquant.egg-info
# writing vnquant.egg-info/PKG-INFO
# writing dependency_links to vnquant.egg-info/dependency_links.txt
# writing requirements to vnquant.egg-info/requires.txt
# writing top-level names to vnquant.egg-info/top_level.txt
# writing manifest file 'vnquant.egg-info/SOURCES.txt'
# reading manifest file 'vnquant.egg-info/SOURCES.txt'
# writing manifest file 'vnquant.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/vnquant
# copying vnquant/__init__.py -> build/lib/vnquant
# copying vnquant/__version__.py -> build/lib/vnquant
# copying vnquant/utils.py -> build/lib/vnquant
# creating build/lib/vnquant/configs
# copying vnquant/configs/__init__.py -> build/lib/vnquant/configs
# copying vnquant/configs/configs.py -> build/lib/vnquant/configs
# creating build/lib/vnquant/plot
# copying vnquant/plot/__init__.py -> build/lib/vnquant/plot
# copying vnquant/plot/Plot.py -> build/lib/vnquant/plot
# copying vnquant/plot/plot.py -> build/lib/vnquant/plot
# creating build/lib/vnquant/utils
# copying vnquant/utils/__init__.py -> build/lib/vnquant/utils
# copying vnquant/utils/utils.py -> build/lib/vnquant/utils
# creating build/lib/vnquant/data
# copying vnquant/data/__init__.py -> build/lib/vnquant/data
# copying vnquant/data/finance.py -> build/lib/vnquant/data
# copying vnquant/data/dataloader.py -> build/lib/vnquant/data
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/vnquant
# creating build/bdist.linux-x86_64/egg/vnquant/configs
# copying build/lib/vnquant/configs/__init__.py -> build/bdist.linux-x86_64/egg/vnquant/configs
# copying build/lib/vnquant/configs/configs.py -> build/bdist.linux-x86_64/egg/vnquant/configs
# creating build/bdist.linux-x86_64/egg/vnquant/plot
# copying build/lib/vnquant/plot/__init__.py -> build/bdist.linux-x86_64/egg/vnquant/plot
# copying build/lib/vnquant/plot/Plot.py -> build/bdist.linux-x86_64/egg/vnquant/plot
# copying build/lib/vnquant/plot/plot.py -> build/bdist.linux-x86_64/egg/vnquant/plot
# copying build/lib/vnquant/__init__.py -> build/bdist.linux-x86_64/egg/vnquant
# creating build/bdist.linux-x86_64/egg/vnquant/utils
# copying build/lib/vnquant/utils/__init__.py -> build/bdist.linux-x86_64/egg/vnquant/utils
# copying build/lib/vnquant/utils/utils.py -> build/bdist.linux-x86_64/egg/vnquant/utils
# creating build/bdist.linux-x86_64/egg/vnquant/data
# copying build/lib/vnquant/data/__init__.py -> build/bdist.linux-x86_64/egg/vnquant/data
# copying build/lib/vnquant/data/finance.py -> build/bdist.linux-x86_64/egg/vnquant/data
# copying build/lib/vnquant/data/dataloader.py -> build/bdist.linux-x86_64/egg/vnquant/data
# copying build/lib/vnquant/__version__.py -> build/bdist.linux-x86_64/egg/vnquant
# copying build/lib/vnquant/utils.py -> build/bdist.linux-x86_64/egg/vnquant
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/configs/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/configs/configs.py to configs.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/plot/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/plot/Plot.py to Plot.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/plot/plot.py to plot.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/utils/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/utils/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/data/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/data/finance.py to finance.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/data/dataloader.py to dataloader.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/__version__.py to __version__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/vnquant/utils.py to utils.cpython-39.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying vnquant.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/vnquant-0.1.1-py3.9.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing vnquant-0.1.1-py3.9.egg
# creating /usr/local/lib/python3.9/dist-packages/vnquant-0.1.1-py3.9.egg
# Extracting vnquant-0.1.1-py3.9.egg to /usr/local/lib/python3.9/dist-packages
# Adding vnquant 0.1.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.9/dist-packages/vnquant-0.1.1-py3.9.egg
# Processing dependencies for vnquant==0.1.1
# Searching for bs4>=0.0.1
# Reading https://pypi.org/simple/bs4/
# Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz#sha256=36ecea1fd7cc5c0c6e4a1ff075df26d50da647b75376626cc186e2212886dd3a
# Best match: bs4 0.0.1
# Processing bs4-0.0.1.tar.gz
# Writing /tmp/easy_install-m2teppbt/bs4-0.0.1/setup.cfg
# Running bs4-0.0.1/setup.py -q bdist_egg --dist-dir /tmp/easy_install-m2teppbt/bs4-0.0.1/egg-dist-tmp-686ncmnp
# package init file 'temp/__init__.py' not found (or not a regular file)
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# warning: install_lib: 'build/lib' does not exist -- no Python modules to install
#
# zip_safe flag not set; analyzing archive contents...
# Moving bs4-0.0.1-py3.9.egg to /usr/local/lib/python3.9/dist-packages
# Adding bs4 0.0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.9/dist-packages/bs4-0.0.1-py3.9.egg
# Searching for pypandoc>=1.4
# Reading https://pypi.org/simple/pypandoc/
# Downloading https://files.pythonhosted.org/packages/59/ac/1380f19d6bab8772b4e40d881091039a8c592d66382bd4c865fa21373bad/pypandoc-1.11-py3-none-any.whl#sha256=b260596934e9cfc6513056110a7c8600171d414f90558bf4407e68b209be8007
# Best match: pypandoc 1.11
# Processing pypandoc-1.11-py3-none-any.whl
# Installing pypandoc-1.11-py3-none-any.whl to /usr/local/lib/python3.9/dist-packages
# Adding pypandoc 1.11 to easy-install.pth file
#
# Installed /usr/local/lib/python3.9/dist-packages/pypandoc-1.11-py3.9.egg
# Searching for plotly==5.13.1
# Best match: plotly 5.13.1
# Adding plotly 5.13.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for lxml==4.9.2
# Best match: lxml 4.9.2
# Adding lxml 4.9.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for wrapt==1.14.1
# Best match: wrapt 1.14.1
# Adding wrapt 1.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for requests==2.27.1
# Best match: requests 2.27.1
# Adding requests 2.27.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for numpy==1.22.4
# Best match: numpy 1.22.4
# Adding numpy 1.22.4 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.9 script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pandas==1.5.3
# Best match: pandas 1.5.3
# Adding pandas 1.5.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for beautifulsoup4==4.11.2
# Best match: beautifulsoup4 4.11.2
# Adding beautifulsoup4 4.11.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tenacity==8.2.2
# Best match: tenacity 8.2.2
# Adding tenacity 8.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for idna==3.4
# Best match: idna 3.4
# Adding idna 3.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for charset-normalizer==2.0.12
# Best match: charset-normalizer 2.0.12
# Adding charset-normalizer 2.0.12 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for certifi==2022.12.7
# Best match: certifi 2022.12.7
# Adding certifi 2022.12.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for urllib3==1.26.15
# Best match: urllib3 1.26.15
# Adding urllib3 1.26.15 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pytz==2022.7.1
# Best match: pytz 2022.7.1
# Adding pytz 2022.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for soupsieve==2.4.1
# Best match: soupsieve 2.4.1
# Adding soupsieve 2.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Finished processing dependencies for vnquant==0.1.1

# %%
import vnquant.DataLoader as web
loader = web.DataLoader('FPT', '2019-01-01','2022-04-22')
data= loader.download()
data.head()
# Out:
# /content/vnquant/vnquant/DataLoader.py:254: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   stock_data['change_perc1'], stock_data['change_perc2'] = stock_data['change_perc'].apply(utils.split_change_col).str
# 2022-04-25 12:15:47,007 : INFO : data FPT from 2019-01-01 to 2022-04-22 have already cloned!
# Attributes   high    low   open close adjust  volume
# Symbols       FPT    FPT    FPT   FPT    FPT     FPT
# date
# 2019-01-02  42.15  41.15  41.20  41.2  25.63  539120
# 2019-01-03  41.45  40.70  41.45  40.8  25.38  796600
# 2019-01-04  41.45  40.50  40.60  41.1  25.57  378570
# 2019-01-07  42.10  41.60  41.80  41.8  26.01  408470
# 2019-01-08  42.00  41.70  41.80  42.0  26.13  295660

# %%
data.shape
# Out:
# (822, 6)

# %%
from vnquant import Plot
Plot._vnquant_candle_stick(data = data,
                      title='FPT Price from 2019-01-01 to 2022-04-22',
                      ylab='Date', xlab='Price',
                      show_vol=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a1c5538d-7e1a-4253-a260-3f84c8a9d110" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1c5538d-7e1a-4253-a260-3f84c8a9d110")) {                    Plotly.newPlot(                        "a1c5538d-7e1a-4253-a260-3f84c8a9d110",                        [{"close":[41.2,40.8,41.1,41.8,42.0,42.4,42.15,42.2,42.5,42.8,42.55,42.0,42.0,42.5,42.35,42.35,42.45,42.4,42.1,42.5,43.2,43.2,42.6,44.15,43.9,44.55,44.25,44.2,44.4,44.4,44.85,44.8,45.2,45.5,45.2,45.1,44.2,44.6,45.0,44.9,44.6,44.75,44.65,44.5,46.5,46.2,46.25,46.0,46.2,45.7,45.45,45.1,45.05,44.4,44.75,45.0,45.15,45.5,45.8,46.0,47.2,47.8,47.8,47.8,47.3,46.9,47.0,48.2,47.9,48.5,48.5,48.45,47.9,47.9,48.55,48.8,49.55,49.85,50.0,48.75,49.7,49.65,48.6,49.0,49.5,50.2,50.4,49.65,44.45,45.25,45.9,45.25,45.7,45.6,45.25,44.85,44.1,44.55,44.1,43.5,43.3,43.6,44.5,45.2,45.1,45.2,45.05,44.55,44.4,44.05,44.05,44.65,45.4,45.4,45.15,46.5,46.15,45.4,45.5,47.1,46.9,46.8,46.95,46.6,46.3,46.75,47.05,47.0,47.0,47.3,47.3,47.05,46.8,48.2,48.35,48.8,48.6,48.65,48.8,48.6,47.8,48.4,48.35,48.8,49.0,48.95,49.75,50.3,51.1,52.3,52.5,53.2,53.0,52.0,52.4,54.0,53.6,53.0,54.4,53.7,52.8,52.1,52.7,53.1,53.7,53.2,52.6,52.9,53.8,54.0,54.1,56.5,56.8,57.7,57.6,56.4,57.8,58.2,56.5,56.2,57.4,57.7,58.5,57.7,58.5,57.2,57.2,56.8,55.5,56.1,56.4,56.4,56.5,57.7,57.4,57.5,56.7,57.1,56.5,56.3,56.4,58.2,58.0,58.1,57.9,57.8,57.9,58.5,59.9,59.8,59.5,59.5,59.6,60.0,61.0,60.5,58.3,58.6,57.5,58.3,56.8,56.0,56.0,56.6,57.1,57.0,56.0,56.4,54.6,54.5,55.4,54.9,55.0,55.3,55.5,56.5,57.0,57.1,56.5,55.4,55.5,55.8,56.5,56.1,56.4,57.5,57.4,57.6,58.6,58.3,58.6,57.6,57.0,58.1,56.8,57.6,57.5,57.1,57.0,57.0,58.0,57.6,57.4,55.5,56.5,54.7,52.0,51.5,51.8,52.0,53.6,53.3,52.6,53.6,54.1,54.3,54.5,54.2,56.0,55.7,55.8,54.7,52.5,54.0,55.0,56.0,55.1,55.7,55.9,55.5,54.6,54.0,50.3,51.7,50.8,48.1,48.15,47.6,48.5,48.4,47.7,47.7,44.4,44.5,46.0,44.2,43.1,40.4,41.1,42.3,44.6,47.5,47.3,46.85,46.85,46.4,46.5,49.5,50.1,50.3,51.2,51.3,49.3,51.1,51.0,51.0,50.7,50.7,50.8,50.5,50.9,52.9,53.5,53.7,54.0,54.4,49.35,48.7,48.0,48.35,49.25,48.9,49.3,48.45,48.45,48.8,48.0,48.0,47.95,48.3,48.0,48.65,48.4,48.7,49.35,48.95,48.8,46.0,47.0,46.0,46.6,46.35,46.6,47.0,47.0,47.55,47.2,46.8,46.85,46.05,45.65,46.2,46.15,46.25,46.8,47.45,47.7,48.35,47.8,48.65,48.55,48.6,48.6,48.1,47.4,47.8,47.4,47.75,45.9,43.7,45.7,44.55,45.15,44.5,45.9,46.55,47.0,46.8,47.1,47.2,47.0,47.5,47.95,47.8,47.0,46.85,46.85,47.05,47.4,48.45,48.85,48.4,49.85,49.9,49.5,49.9,50.4,50.0,48.5,49.5,49.2,49.2,49.15,49.3,50.0,50.5,50.0,51.2,51.2,51.3,51.1,50.5,50.8,51.1,50.2,50.0,50.8,50.3,50.5,50.5,50.4,51.1,50.8,50.9,50.7,51.0,51.2,53.2,53.3,53.2,52.8,54.0,53.9,52.8,52.1,50.7,50.9,51.5,51.7,52.8,53.0,52.0,52.4,53.4,53.0,53.0,53.5,53.8,53.3,54.0,54.0,55.1,55.2,55.9,55.2,55.7,56.2,55.4,55.2,55.6,55.6,55.7,55.7,56.2,57.5,56.5,57.0,57.2,56.7,57.1,56.5,56.9,57.5,58.1,57.5,57.0,57.6,57.9,58.6,58.1,59.1,60.2,62.7,62.4,62.5,63.3,64.7,65.8,66.5,66.4,66.6,66.3,62.0,63.3,65.6,66.9,67.0,66.0,63.0,58.6,62.7,63.5,66.0,70.0,72.5,72.9,71.3,74.6,77.9,78.2,76.6,76.8,75.5,75.4,76.2,76.2,77.9,77.9,77.7,75.9,75.9,75.8,75.0,76.3,76.7,76.5,76.5,81.0,80.8,81.0,79.8,78.7,78.8,77.0,76.6,76.1,77.6,77.1,77.7,79.7,79.8,79.6,79.4,79.6,79.6,82.1,82.1,80.7,81.0,80.0,79.7,81.5,82.9,80.0,83.0,81.0,80.7,80.8,80.9,82.9,82.9,82.7,83.0,85.8,85.2,85.4,84.0,84.8,85.7,87.0,90.8,95.5,93.8,93.5,93.8,95.3,93.8,94.8,97.9,87.1,85.5,85.2,84.7,82.7,80.8,81.7,81.9,83.5,83.8,83.2,83.1,82.6,83.8,85.6,85.4,84.9,84.7,85.2,85.7,88.6,88.0,88.9,91.9,92.7,87.0,90.5,89.8,89.7,86.1,87.0,85.2,85.4,86.8,84.7,86.8,86.6,89.4,90.5,93.7,93.2,92.0,93.4,94.0,95.6,95.8,95.6,96.6,96.6,97.5,97.8,96.1,93.8,95.0,94.6,93.8,94.0,94.5,92.8,91.0,91.9,91.9,91.4,92.0,92.2,92.4,92.4,94.9,93.5,93.1,93.2,93.5,93.0,93. ...

# %%
import numpy as np
# Tính chuỗi return
r_t = np.log(data['close']/data['close'].shift(1)).values[:, 0]

# %%
mean = np.nanmean(r_t)
r_t[0]=mean
r_t[:5]
# Out:
# array([ 0.0012181 , -0.00975617,  0.00732604,  0.01688822,  0.00477328])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 4))
plt.plot(np.arange(r_t.shape[0]), r_t, '-o')
plt.axhline(y=mean, label='mean return', c='red')
plt.title('Return rate according to date')
plt.xlabel('Date Order')
plt.ylabel('Return Rate')
plt.legend()
plt.show()

# %%
import numpy as np
# Tính chuỗi return
r_t = np.log(data['close']/data['close'].shift(1)).values[:, 0]

# %%
mean = np.nanmean(r_t)
r_t[0]=mean
r_t[:5]
# Out:
# array([ 0.0012181 , -0.00975617,  0.00732604,  0.01688822,  0.00477328])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 4))
plt.plot(np.arange(r_t.shape[0]), r_t, '-o')
plt.axhline(y=mean, label='mean return', c='red')
plt.title('Return rate according to date')
plt.xlabel('Date Order')
plt.ylabel('Return Rate')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.scatter(x=r_t[1:], y=r_t[:-1])
plt.title('Return rate vs Lag order 1 according to date')
plt.xlabel('r(t-1)')
plt.ylabel('r(t)')
plt.show()

# %% [markdown]
# Đồ thị cho thấy 2 chuỗi có mối quan hệ tương quan vàvà thấy rõ chúng là 1 trend tăng.

# %%
import seaborn as sns

plt.figure(figsize = (8, 6))
sns.distplot(r_t, bins = 20)
plt.axvline(x=mean, label='mean return', c='red')
plt.title('Distribution return of FPT')
plt.legend()
plt.xlabel('return rate')
plt.ylabel('frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# Text(0, 0.5, 'frequency')

# %%
import statsmodels.api as sm
sm.qqplot(r_t)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
from scipy import stats
tq = stats.probplot(r_t)
plt.scatter(x=tq[0][0], y = tq[0][1])
plt.show()

# %% [markdown]
# Check stationary

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(r_t)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -10.211857
# p-value: 0.000000
# Critical Values:
# 	1%: -3.438
# 	5%: -2.865
# 	10%: -2.569

# %% [markdown]
# Build ARIMA model

# %%
Auto Regressive (AR): p
Integrated (I): d
Moving Average (MA): q

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 6))
ax1 = plot_acf(r_t)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 6))
ax2 = plot_pacf(r_t)

# %% [markdown]
# Manual ARIMA

# %%
from statsmodels.tsa.arima_model import ARIMA

def _arima_fit(orders, data):
  models = dict()
  for order in orders:
    model = ARIMA(data, order = order).fit()
    model_name = 'ARIMA({},{},{})'.format(order[0], order[1], order[2])
    print('{} --> AIC={}; BIC={}'.format(model_name, model.aic, model.bic))
    models[model_name] = model
  return models

orders = [(2, 0, 2), (2, 0, 0), (5, 0, 0), (0, 0, 5)]
models = _arima_fit(orders, r_t)
# Out:
# ARIMA(2,0,2) --> AIC=-4258.981816393252; BIC=-4230.711374022915
# ARIMA(2,0,0) --> AIC=-4254.555450096328; BIC=-4235.708488516103
# ARIMA(5,0,0) --> AIC=-4251.159790219541; BIC=-4218.177607454148
# ARIMA(0,0,5) --> AIC=-4250.841361078543; BIC=-4217.85917831315

# %% [markdown]
# => Mô hình ARIMA (2,0,2) là tốt nhất vì AIC nhỏ nhất

# %%
from statsmodels.tsa.arima_model import ARIMA

model_arima = ARIMA(r_t, order = (2, 0, 2))
model_fit = model_arima.fit()
print(model_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  822
# Model:                     ARMA(2, 2)   Log Likelihood                2135.491
# Method:                       css-mle   S.D. of innovations              0.018
# Date:                Fri, 22 Apr 2022   AIC                          -4258.982
# Time:                        13:28:10   BIC                          -4230.711
# Sample:                             0   HQIC                         -4248.136
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      1.909      0.057   -3.27e-05       0.002
# ar.L1.y        0.5237      0.010     52.263      0.000       0.504       0.543
# ar.L2.y       -0.9786      0.009   -107.318      0.000      -0.996      -0.961
# ma.L1.y       -0.5127      0.005   -103.865      0.000      -0.522      -0.503
# ma.L2.y        0.9999      0.005    198.809      0.000       0.990       1.010
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.2676           -0.9748j            1.0109           -0.2074
# AR.2            0.2676           +0.9748j            1.0109            0.2074
# MA.1            0.2564           -0.9666j            1.0000           -0.2087
# MA.2            0.2564           +0.9666j            1.0000            0.2087
# -----------------------------------------------------------------------------

# %%
model_fit.forecast(steps=30)[0]
# Out:
# array([ 3.15832482e-03,  2.69305238e-03,  9.83770098e-05, -8.05181831e-04,
#         1.26082087e-03,  3.22707591e-03,  2.23500223e-03, -2.08795104e-04,
#        -5.17794794e-04,  1.71193801e-03,  3.18209120e-03,  1.76996804e-03,
#        -4.08320155e-04, -1.67195942e-04,  2.09081435e-03,  3.03741176e-03,
#         1.32341830e-03, -5.00600697e-04,  2.21479766e-04,  2.38468013e-03,
#         2.81094750e-03,  9.17229627e-04, -4.91706589e-04,  6.23644403e-04,
#         2.58659825e-03,  2.52312771e-03,  5.68890090e-04, -3.92471566e-04,
#         1.01650985e-03,  2.69523626e-03])

# %%
data.reset_index(level='date',inplace=True)

# %%
data.shape
# Out:
# (824, 7)

# %%
data.columns= ['Date','High','Low','Open','Closed','Adjust','Volume']

# %%
data = data[['Date','Closed']]

# %%
data.head(5)
# Out:
#         Date  Closed
# 0 2019-01-02    41.2
# 1 2019-01-03    40.8
# 2 2019-01-04    41.1
# 3 2019-01-07    41.8
# 4 2019-01-08    42.0

# %%
import datetime

# %%
(data['Date'][2]-data['Date'][1]).days
# Out:
# 1

# %%
(data['Date'][2]-data['Date'][3]).days
# Out:
# -3

# %%
data['Date'][0]
# Out:
# Timestamp('2019-01-02 00:00:00')

# %%
data['Date'][0] + datetime.timedelta(days=1)
# Out:
# Timestamp('2019-01-03 00:00:00')

# %%
data['Date'][823]
# Out:
# Timestamp('2022-04-22 00:00:00')

# %%
for i in range(len(data['Date'])):
  if (data['Date'][i]-data['Date'][i+1]) != (-1):
    a = data['Date'].to_list()
    a.append(str(data['Date'][i] + datetime.timedelta(days=1)))
    a.append(str(data['Date'][i] + datetime.timedelta(days=2)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 824 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-73fe3ef557b2> in <module>()
#       1 for i in range(len(data['Date'])):
# ----> 2   if (data['Date'][i]-data['Date'][i+1]) != (-1):
#       3     a = data['Date'].to_list()
#       4     a.append(str(data['Date'][i] + datetime.timedelta(days=1)))
#       5     a.append(str(data['Date'][i] + datetime.timedelta(days=2)))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 824

# %%
#!pip install pycaret

# %%
from pycaret.utils import enable_colab

# %%
#!pip install pycaret-ts-alpha

# %%
from pycaret.time_series import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-99c32ed8ebd7> in <module>()
# ----> 1 from pycaret.time_series import *
#
# ModuleNotFoundError: No module named 'pycaret'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
train.to_csv('train.csv',index=False)

# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv')

# %%
train['Date'] = pd.to_datetime(train['Date'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 809 entries, 0 to 808
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    809 non-null    datetime64[ns]
#  1   Closed  809 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 12.8 KB

# %%
train.sort_values('Date',ascending=True)
# Out:
#            Date  Closed
# 0    2019-01-02    41.2
# 1    2019-01-03    40.8
# 2    2019-01-04    41.1
# 3    2019-01-07    41.8
# 4    2019-01-08    42.0
# ..          ...     ...
# 804  2022-03-25    95.7
# 805  2022-03-28    98.1
# 806  2022-03-29   104.9
# 807  2022-03-30   106.0
# 808  2022-03-31   107.0
#
# [809 rows x 2 columns]

# %%
data
# Out:
#           Date  Closed
# 0   2019-01-02    41.2
# 1   2019-01-03    40.8
# 2   2019-01-04    41.1
# 3   2019-01-07    41.8
# 4   2019-01-08    42.0
# ..         ...     ...
# 817 2022-04-14   116.6
# 818 2022-04-15   115.0
# 819 2022-04-18   115.5
# 820 2022-04-19   112.0
# 821 2022-04-20   112.0
#
# [822 rows x 2 columns]

# %%
import datetime

# %% [markdown]
# Auto ARIMA

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.2 MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.3.5)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 38.1 MB/s
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.8)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.5 statsmodels-0.13.2

# %%
import pmdarima as pm
model = pm.auto_arima(r_t, start_p=0, start_q=0,
                           max_p=5, max_q=5, m=12,
                           start_P=0, seasonal=False,
                           d=0, D=0, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)

print(model.aic())
# Out:
# /usr/local/lib/python3.7/dist-packages/pmdarima/arima/_validation.py:62: UserWarning:
#
# m (12) set for non-seasonal fit. Setting to 0
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-2923.004, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-2924.918, Time=0.11 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-2924.736, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-2923.159, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-2923.095, Time=0.07 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-2921.189, Time=0.19 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-2925.340, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-2923.073, Time=0.11 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-2923.496, Time=0.12 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-2923.455, Time=0.17 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-2925.169, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-2921.520, Time=0.49 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 1.819 seconds
# -2925.3403272548867

# %% [markdown]
# => Auto Arima gợi ý mô hình ARIMA(1,0,0)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  696
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                1465.670
# Date:                Tue, 26 Oct 2021   AIC                          -2925.340
# Time:                        13:59:26   BIC                          -2911.704
# Sample:                             0   HQIC                         -2920.068
#                                 - 696
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0017      0.001      1.334      0.182      -0.001       0.004
# ar.L1         -0.0783      0.028     -2.772      0.006      -0.134      -0.023
# sigma2         0.0009   1.38e-05     63.037      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (Q):                       73.14   Jarque-Bera (JB):            101267.53
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              13.75   Skew:                            -3.98
# Prob(H) (two-sided):                  0.00   Kurtosis:                        61.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model = ARIMA(r_t, order=(1,0,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  696
# Model:                     ARMA(1, 0)   Log Likelihood                1465.670
# Method:                       css-mle   S.D. of innovations              0.029
# Date:                Tue, 26 Oct 2021   AIC                          -2925.340
# Time:                        14:05:57   BIC                          -2911.704
# Sample:                             0   HQIC                         -2920.068
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.001      1.560      0.119      -0.000       0.004
# ar.L1.y       -0.0782      0.038     -2.069      0.039      -0.152      -0.004
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -12.7892           +0.0000j           12.7892            0.5000
# -----------------------------------------------------------------------------

# %%
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# Actual vs Fitted
model_fit.plot_predict(dynamic=False)
plt.show()

# %% [markdown]
# Như vậy đã train model xong, giờ chúng ta dùng nó để forecast

# %% [markdown]
# Test 2
#
# Auto Arima nhanh gọn lẹ

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/wwwusage.csv', names=['value'], header=0)

# %%
df.head(10)
# Out:
#    value
# 0     88
# 1     84
# 2     85
# 3     85
# 4     84
# 5     85
# 6     83
# 7     85
# 8     88
# 9     89

# %%
model = pm.auto_arima(df.value, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=525.587, Time=0.12 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=533.474, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=532.437, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=525.893, Time=0.04 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=531.477, Time=0.01 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=515.248, Time=0.08 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=513.459, Time=0.05 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=515.284, Time=0.07 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(2,2,0)(0,0,0)[0]             : AIC=511.465, Time=0.03 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=530.444, Time=0.02 sec
#  ARIMA(3,2,0)(0,0,0)[0]             : AIC=513.291, Time=0.04 sec
#  ARIMA(2,2,1)(0,0,0)[0]             : AIC=513.256, Time=0.05 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=523.592, Time=0.03 sec
#  ARIMA(3,2,1)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#
# Best model:  ARIMA(2,2,0)(0,0,0)[0]
# Total fit time: 1.422 seconds
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:               SARIMAX(2, 2, 0)   Log Likelihood                -252.732
# Date:                Tue, 26 Oct 2021   AIC                            511.465
# Time:                        14:20:47   BIC                            519.220
# Sample:                             0   HQIC                           514.601
#                                 - 100
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2579      0.103      2.510      0.012       0.056       0.459
# ar.L2         -0.4407      0.087     -5.093      0.000      -0.610      -0.271
# sigma2        10.1268      1.519      6.668      0.000       7.150      13.103
# ===================================================================================
# Ljung-Box (Q):                       38.89   Jarque-Bera (JB):                 0.10
# Prob(Q):                              0.52   Prob(JB):                         0.95
# Heteroskedasticity (H):               0.49   Skew:                            -0.07
# Prob(H) (two-sided):                  0.05   Kurtosis:                         2.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(7,5))
plt.show()

# %%
# Forecast
n_periods = 24
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = np.arange(len(df.value), len(df.value)+n_periods)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(df.value)
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("Final Forecast of WWW Usage")
plt.show()

# %% [markdown]
# Test with seasonal data

# %%
# Import
data = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'], index_col='date')

# %%
data.head(10)
# Out:
#                value
# date
# 1991-07-01  3.526591
# 1991-08-01  3.180891
# 1991-09-01  3.252221
# 1991-10-01  3.611003
# 1991-11-01  3.565869
# 1991-12-01  4.306371
# 1992-01-01  5.088335
# 1992-02-01  2.814520
# 1992-03-01  2.985811
# 1992-04-01  3.204780

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)
# Usual Differencing
axes[0].plot(data[:], label='Original Series')
axes[0].plot(data[:].diff(1), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)
# Seasinal Dei
axes[1].plot(data[:], label='Original Series')
axes[1].plot(data[:].diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('a10 - Drug Sales', fontsize=16)
plt.show()

# %%
# !pip3 install pyramid-arima
import pmdarima as pm

# Seasonal - fit stepwise auto-ARIMA
smodel = pm.auto_arima(data, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=12,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

smodel.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=534.818, Time=1.98 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=624.061, Time=0.03 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=596.068, Time=0.72 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=611.475, Time=0.56 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=757.274, Time=0.03 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=559.407, Time=0.39 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=3.27 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=536.817, Time=6.11 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=543.106, Time=1.95 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=537.671, Time=9.39 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=594.467, Time=0.49 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=529.829, Time=2.01 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=555.198, Time=0.47 sec
#  ARIMA(2,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=4.07 sec
#  ARIMA(2,0,1)(0,1,2)[12] intercept   : AIC=531.168, Time=5.39 sec
#  ARIMA(2,0,1)(1,1,0)[12] intercept   : AIC=534.757, Time=1.93 sec
#  ARIMA(2,0,1)(1,1,2)[12] intercept   : AIC=524.202, Time=10.18 sec
#  ARIMA(2,0,1)(2,1,2)[12] intercept   : AIC=533.034, Time=9.56 sec
#  ARIMA(2,0,1)(2,1,1)[12] intercept   : AIC=532.041, Time=10.41 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=545.610, Time=6.95 sec
#  ARIMA(3,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=10.60 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=524.354, Time=12.84 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=593.876, Time=4.52 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=523.916, Time=10.83 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=532.804, Time=7.58 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=4.47 sec
#  ARIMA(1,0,2)(2,1,2)[12] intercept   : AIC=534.472, Time=11.61 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=531.170, Time=2.45 sec
#  ARIMA(1,0,2)(2,1,1)[12] intercept   : AIC=532.815, Time=7.91 sec
#  ARIMA(0,0,2)(1,1,2)[12] intercept   : AIC=583.617, Time=5.23 sec
#  ARIMA(1,0,3)(1,1,2)[12] intercept   : AIC=inf, Time=10.50 sec
#  ARIMA(0,0,1)(1,1,2)[12] intercept   : AIC=614.924, Time=4.02 sec
#  ARIMA(0,0,3)(1,1,2)[12] intercept   : AIC=566.118, Time=6.89 sec
#  ARIMA(2,0,3)(1,1,2)[12] intercept   : AIC=527.480, Time=11.95 sec
#  ARIMA(1,0,2)(1,1,2)[12]             : AIC=524.136, Time=6.86 sec
#
# Best model:  ARIMA(1,0,2)(1,1,2)[12] intercept
# Total fit time: 194.239 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  204
# Model:             SARIMAX(1, 0, 2)x(1, 1, 2, 12)   Log Likelihood                -253.958
# Date:                            Tue, 26 Oct 2021   AIC                            523.916
# Time:                                    14:25:31   BIC                            549.976
# Sample:                                         0   HQIC                           534.471
#                                             - 204
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0054      0.009      0.579      0.562      -0.013       0.024
# ar.L1          0.9762      0.019     51.973      0.000       0.939       1.013
# ma.L1         -0.9076      0.057    -15.899      0.000      -1.020      -0.796
# ma.L2          0.2172      0.059      3.674      0.000       0.101       0.333
# ar.S.L12       0.8390      0.159      5.268      0.000       0.527       1.151
# ma.S.L12      -1.5790      0.180     -8.794      0.000      -1.931      -1.227
# ma.S.L24       0.7615      0.112      6.794      0.000       0.542       0.981
# sigma2         0.7549      0.067     11.333      0.000       0.624       0.885
# ===================================================================================
# Ljung-Box (Q):                       68.95   Jarque-Bera (JB):               143.00
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              14.46   Skew:                             0.30
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Forecast
n_periods = 24
fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(data.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(data)
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Final Forecast of a10 - Drug Sales")
plt.show()

# %% [markdown]
# Holt Winter Analysis

# %%
# dataframe opertations - pandas
import pandas as pd
# plotting data - matplotlib
from matplotlib import pyplot as plt
# time series - statsmodels 
# Seasonality decomposition
from statsmodels.tsa.seasonal import seasonal_decompose
# holt winters 
# single exponential smoothing
from statsmodels.tsa.holtwinters import SimpleExpSmoothing   
# double and triple exponential smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
airline = pd.read_csv('https://raw.githubusercontent.com/maxtran1997gmail/Files/main/international-airline-passengers.csv',header = 0,index_col='Month',names=['Month','Thousands of Passengers'], parse_dates=True)

# %%
airline = airline[0:144]

# %%
airline.head(5)
# Out:
#          Thousands of Passengers
# Month
# 1949-01                    112.0
# 1949-02                    118.0
# 1949-03                    132.0
# 1949-04                    129.0
# 1949-05                    121.0

# %%
# finding shape of the dataframe
print(airline.shape)
# having a look at the data
print(airline.head())
# plotting the original data
airline[['Thousands of Passengers']].plot(title='Passengers Data')
# Out:
# (144, 1)
#          Thousands of Passengers
# Month
# 1949-01                    112.0
# 1949-02                    118.0
# 1949-03                    132.0
# 1949-04                    129.0
# 1949-05                    121.0

# %%
airline.dtypes
# Out:
# Thousands of Passengers    float64
# dtype: object

# %%
airline.index
# Out:
# Index(['1949-01', '1949-02', '1949-03', '1949-04', '1949-05', '1949-06',
#        '1949-07', '1949-08', '1949-09', '1949-10',
#        ...
#        '1960-03', '1960-04', '1960-05', '1960-06', '1960-07', '1960-08',
#        '1960-09', '1960-10', '1960-11', '1960-12'],
#       dtype='object', name='Month', length=144)

# %%
airline.index = pd.to_datetime(airline.index)

# %%
# decompose the time series
decompose_result = seasonal_decompose(airline['Thousands of Passengers'],model='multiplicative')

# %%
decompose_result.plot()

# %%
decompose_result.plot();

# %%
airline.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                    112.0
# 1949-02-01                    118.0
# 1949-03-01                    132.0
# 1949-04-01                    129.0
# 1949-05-01                    121.0

# %%
airline.dropna(inplace=True)

# %%
airline['6-month-SMA'] = airline['Thousands of Passengers'].rolling(window=6).mean()

# %%
airline['12-month-SMA'] = airline['Thousands of Passengers'].rolling(window=12).mean()

# %%
airline.plot(title='Simple Moving Averages');

# %%
airline.head(12)
# Out:
#             Thousands of Passengers  6-month-SMA  12-month-SMA
# Month
# 1949-01-01                    112.0          NaN           NaN
# 1949-02-01                    118.0          NaN           NaN
# 1949-03-01                    132.0          NaN           NaN
# 1949-04-01                    129.0          NaN           NaN
# 1949-05-01                    121.0          NaN           NaN
# 1949-06-01                    135.0   124.500000           NaN
# 1949-07-01                    148.0   130.500000           NaN
# 1949-08-01                    148.0   135.500000           NaN
# 1949-09-01                    136.0   136.166667           NaN
# 1949-10-01                    119.0   134.500000           NaN
# 1949-11-01                    104.0   131.666667           NaN
# 1949-12-01                    118.0   128.833333    126.666667

# %%
airline['ewma12'] = airline['Thousands of Passengers'].ewm(span=12,adjust=False).mean()

# %%
airline[['Thousands of Passengers','ewma12']].plot();

# %%
airline[['Thousands of Passengers','ewma12','6-month-SMA','12-month-SMA']].plot();

# %%
# set the span and the smoothing factor alpha
span = 12
alpha = 2/(span+1)

# %%
airline.columns
# Out:
# Index(['Thousands of Passengers', '6-month-SMA', '12-month-SMA', 'ewma12'], dtype='object')

# %%
# Set the frequency of the date time index as Monthly start as indicated by the data
airline.index.freq = 'MS'

# %%
airline.head()
# Out:
#             Thousands of Passengers  6-month-SMA  12-month-SMA      ewma12
# Month
# 1949-01-01                    112.0          NaN           NaN  112.000000
# 1949-02-01                    118.0          NaN           NaN  112.923077
# 1949-03-01                    132.0          NaN           NaN  115.857988
# 1949-04-01                    129.0          NaN           NaN  117.879836
# 1949-05-01                    121.0          NaN           NaN  118.359861

# %%
airline.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq='MS')

# %%
airline['SES12'] = SimpleExpSmoothing(airline['Thousands of Passengers']).fit(smoothing_level=alpha,optimized=False).fittedvalues.shift(-1)

# %%
airline.head()
# Out:
#             Thousands of Passengers  6-month-SMA  ...      ewma12       SES12
# Month                                             ...
# 1949-01-01                    112.0          NaN  ...  112.000000  112.000000
# 1949-02-01                    118.0          NaN  ...  112.923077  112.923077
# 1949-03-01                    132.0          NaN  ...  115.857988  115.857988
# 1949-04-01                    129.0          NaN  ...  117.879836  117.879836
# 1949-05-01                    121.0          NaN  ...  118.359861  118.359861
#
# [5 rows x 5 columns]

# %%
airline[['Thousands of Passengers','ewma12','SES12']].plot(title='Pandas EWMA and Statsmodels Holt Winters Single Exponential Smoothing');

# %%
airline['DES12'] = ExponentialSmoothing(airline['Thousands of Passengers'],trend='add').fit().fittedvalues.shift(-1)

# %%
airline[['Thousands of Passengers','SES12','DES12']].plot(title='Holt Winters Single & Double Exponential Smoothing');

# %%
airline[['Thousands of Passengers','SES12','DES12']].iloc[:24].plot(title='Holt Winters Single & Double Exponential Smoothing Last 24 months').autoscale(axis='x',tight=True);

# %%
airline['DES12_mul'] = ExponentialSmoothing(airline['Thousands of Passengers'],trend='mul').fit().fittedvalues.shift(-1)

# %%
airline[['Thousands of Passengers','DES12','DES12_mul']].iloc[:24].plot(title='Holt Winters Double Exponential Smoothing Last (Additive vs Multiplicative)').autoscale(axis='x',tight=True);

# %%
airline['TESadd12'] = ExponentialSmoothing(airline['Thousands of Passengers'],trend='add',seasonal='add',seasonal_periods=12).fit().fittedvalues
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.

# %%
airline.head()
# Out:
#             Thousands of Passengers  6-month-SMA  ...   DES12_mul    TESadd12
# Month                                             ...
# 1949-01-01                    112.0          NaN  ...  112.049247  113.081288
# 1949-02-01                    118.0          NaN  ...  118.051885  120.550747
# 1949-03-01                    132.0          NaN  ...  132.058041  135.527329
# 1949-04-01                    129.0          NaN  ...  129.056722  133.155064
# 1949-05-01                    121.0          NaN  ...  121.053204  125.656114
#
# [5 rows x 8 columns]

# %%
airline['TESmul12'] = ExponentialSmoothing(airline['Thousands of Passengers'],trend='mul',seasonal='mul',seasonal_periods=12).fit().fittedvalues

# %%
airline[['Thousands of Passengers','TESadd12','TESmul12']].iloc[:24].plot(title='Holt Winters Triple Exponential Smoothing Last (Additive vs Multiplicative)').autoscale(axis='x',tight=True);

# %%
airline = pd.read_csv('https://raw.githubusercontent.com/maxtran1997gmail/Files/main/international-airline-passengers.csv',header = 0,index_col='Month',names=['Month','Thousands of Passengers'], parse_dates=True)

# %%
airline = airline[0:144]

# %%
train_airline = airline[:108] 
test_airline = airline[108:]

# %%
fitted_model = ExponentialSmoothing(train_airline['Thousands of Passengers'],trend='mul',seasonal='mul',seasonal_periods=12).fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.

# %%
test_predictions = fitted_model.forecast(36).rename('HW Test Forecast')

# %%
test_predictions[:10]
# Out:
# 1958-01-01    356.739143
# 1958-02-01    343.561234
# 1958-03-01    403.996804
# 1958-04-01    397.853537
# 1958-05-01    406.415919
# 1958-06-01    479.824369
# 1958-07-01    529.820371
# 1958-08-01    524.772030
# 1958-09-01    454.714920
# 1958-10-01    391.965458
# Freq: MS, Name: HW Test Forecast, dtype: float64

# %%
train_airline['Thousands of Passengers'].plot(legend=True,label='TRAIN')
test_airline['Thousands of Passengers'].plot(legend=True,label='TEST',figsize=(12,8))
plt.title('Train and Test Data');

# %%
train_airline['Thousands of Passengers'].plot(legend=True,label='TRAIN')
test_airline['Thousands of Passengers'].plot(legend=True,label='TEST',figsize=(12,8))
test_predictions.plot(legend=True,label='PREDICTION')
plt.title('Train, Test and Predicted Test using Holt Winters');

# %%
train_airline['Thousands of Passengers'].plot(legend=True,label='TRAIN')
test_airline['Thousands of Passengers'].plot(legend=True,label='TEST',figsize=(12,8))
test_predictions.plot(legend=True,label='PREDICTION',xlim=['1958-01-01','1961-01-01']);

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
print(f'Mean Absolute Error = {mean_absolute_error(test_airline,test_predictions)}')
print(f'Mean Squared Error = {mean_squared_error(test_airline,test_predictions)}')
# Out:
# Mean Absolute Error = 53.16361991340851
# Mean Squared Error = 3200.583445912333

# %%
test_airline.describe()
# Out:
#        Thousands of Passengers
# count                36.000000
# mean                428.500000
# std                  79.329152
# min                 310.000000
# 25%                 362.000000
# 50%                 412.000000
# 75%                 472.000000
# max                 622.000000

# %%
final_model = ExponentialSmoothing(airline['Thousands of Passengers'],trend='mul',seasonal='mul',seasonal_periods=12).fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.

# %%
forecast_predictions = final_model.forecast(steps=36)

# %%
airline['Thousands of Passengers'].plot(figsize=(12,8),legend=True,label='Current Airline Passengers')
forecast_predictions.plot(legend=True,label='Forecasted Airline Passengers')
plt.title('Airline Passenger Forecast');
